# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img = cv2.imread('pexel1.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# using cv
cv2.imshow('Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # using cv
#       2 cv2.imshow('Image', img)
# ----> 3 cv2.waitKey(0)
#       4 cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
# using matplotlib
img1 = plt.imread('pexel1.jpg')
plt.imshow(img1)

# %%
# using skikit
img2= ski.io.imread('pexel1.jpg')
ski.io.imshow(img2)

# %%
ski.io.imsave('myfile.png', img)
plt.imsave('myfile2.png', img)
cv2.imwrite('myfile3.png', img)
# Out:
# True

# %%
cv2.COLOR_RGB2GRAY
# Out:
# 7

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
ski.io.imshow(img_gray)

# %%
img_gray
# Out:
# array([[252, 254, 253, ..., 220, 221, 221],
#        [251, 247, 251, ..., 220, 220, 221],
#        [254, 247, 251, ..., 220, 220, 221],
#        ...,
#        [206, 208, 212, ..., 130, 130, 134],
#        [204, 207, 213, ..., 128, 132, 140],
#        [206, 210, 218, ..., 127, 134, 143]], dtype=uint8)

# %%
_,img_binary = cv2.threshold(img_gray,50,255, cv2.THRESH_BINARY_INV)
ski.io.imshow(img_binary,)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
vid = cv2.VideoCapture(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 vid = cv2.VideoCapture(0)
#
# NameError: name 'cv2' is not defined

# %%
vid.isopened()

# %%
k = vid.read()

# %%
type(k), len(k)

# %%
flag,img = vid.read()
